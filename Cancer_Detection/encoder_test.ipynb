# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.datasets import make_blobs
from sklearn.decomposition import PCA

from pyod.models.iforest import IForest
from pyod.models.pca import PCA

from sklearn.neighbors import LocalOutlierFactor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report, precision_score, recall_score

import tensorflow as tf

import seaborn as sns
sns.set_style('white')

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# 2023-11-07 22:43:03.129061: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-07 22:43:03.253929: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-07 22:43:03.832785: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-07 22:43:03.832838: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-07 22:43:03.835804: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-07 22:43:04.080804: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-07 22:43:04.083266: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-07 22:43:05.557700: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df = pd.read_csv('data/modified_dataset.csv')

df_stroke_0 = df[df['Cancer'] == 0]
df_stroke_1 = df[df['Cancer'] == 1]



#1.정상으로만 학습, 테스트는 정상과 이상 반반
answer_label = 'Cancer'
X = df[df.columns.difference([answer_label])]
df_normal = df[df[answer_label] == 0]
df_abnormal = df[df[answer_label] == 1]
test_normal_df = df_normal.sample(n=len(df_stroke_1), random_state = 0)
test_df = pd.concat([df_abnormal, test_normal_df])
X_test = test_df[test_df.columns.difference([answer_label])]
y_test = test_df[answer_label]
train_df = df_normal.drop(test_normal_df.index)
X_train = train_df[train_df.columns.difference([answer_label])]
y_train = train_df[answer_label]

# %%
input_dim = X_train.shape[1]

AE = tf.keras.models.Sequential([

    # encode
    tf.keras.layers.Dense(input_dim, activation='elu', input_shape=(input_dim, )),
    tf.keras.layers.Dense(4, activation='elu'),
    tf.keras.layers.Dense(2, activation='elu'),

    # decode
    tf.keras.layers.Dense(4, activation='elu'),
    tf.keras.layers.Dense(input_dim, activation='elu'),
    #tf.keras.layers.Dense(input_dim, activation='sigmoid')
])

AE.compile(optimizer="adam", loss="mse")
AE.summary();
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 4)                 24
#
#  dense_2 (Dense)             (None, 2)                 10
#
#  dense_3 (Dense)             (None, 4)                 12
#
#  dense_4 (Dense)             (None, 5)                 25
#
# =================================================================
# Total params: 101 (404.00 Byte)
# Trainable params: 101 (404.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = AE.fit(
    X_train,
    X_train,
    epochs=200,
    batch_size=16,
    validation_split=0.2
)
# Out:
# Epoch 1/200
# 534/534 [==============================] - 2s 3ms/step - loss: 0.5971 - val_loss: 0.4546
# Epoch 2/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.4278 - val_loss: 0.3917
# Epoch 3/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.3883 - val_loss: 0.3665
# Epoch 4/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.3684 - val_loss: 0.3489
# Epoch 5/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.3535 - val_loss: 0.3342
# Epoch 6/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.3425 - val_loss: 0.3248
# Epoch 7/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.3358 - val_loss: 0.3188
# Epoch 8/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.3314 - val_loss: 0.3150
# Epoch 9/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.3275 - val_loss: 0.3112
# Epoch 10/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.3239 - val_loss: 0.3074
# Epoch 11/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.3201 - val_loss: 0.3044
# Epoch 12/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.3161 - val_loss: 0.2983
# Epoch 13/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.3106 - val_loss: 0.2919
# Epoch 14/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.3042 - val_loss: 0.2836
# Epoch 15/200
# 534/534 [==============================] - 2s 3ms/step - loss: 0.2954 - val_loss: 0.2703
# Epoch 16/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.2851 - val_loss: 0.2578
# Epoch 17/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.2747 - val_loss: 0.2444
# Epoch 18/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.2657 - val_loss: 0.2342
# Epoch 19/200
# 534/534 [==============================] - 2s 3ms/step - loss: 0.2569 - val_loss: 0.2251
# Epoch 20/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.2462 - val_loss: 0.2128
# Epoch 21/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.2309 - val_loss: 0.1996
# Epoch 22/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.2145 - val_loss: 0.1887
# Epoch 23/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.2026 - val_loss: 0.1837
# Epoch 24/200
# 534/534 [==============================] - 2s 3ms/step - loss: 0.1958 - val_loss: 0.1798
# Epoch 25/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1913 - val_loss: 0.1746
# Epoch 26/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1875 - val_loss: 0.1715
# Epoch 27/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1845 - val_loss: 0.1693
# Epoch 28/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1819 - val_loss: 0.1673
# Epoch 29/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1792 - val_loss: 0.1658
# Epoch 30/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1766 - val_loss: 0.1645
# Epoch 31/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1750 - val_loss: 0.1641
# Epoch 32/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1732 - val_loss: 0.1619
# Epoch 33/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1718 - val_loss: 0.1613
# Epoch 34/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1700 - val_loss: 0.1590
# Epoch 35/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1690 - val_loss: 0.1574
# Epoch 36/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1677 - val_loss: 0.1559
# Epoch 37/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1663 - val_loss: 0.1568
# Epoch 38/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1640 - val_loss: 0.1552
# Epoch 39/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1617 - val_loss: 0.1550
# Epoch 40/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1596 - val_loss: 0.1534
# Epoch 41/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1580 - val_loss: 0.1530
# Epoch 42/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1566 - val_loss: 0.1526
# Epoch 43/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1550 - val_loss: 0.1532
# Epoch 44/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1544 - val_loss: 0.1520
# Epoch 45/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1534 - val_loss: 0.1512
# Epoch 46/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1531 - val_loss: 0.1521
# Epoch 47/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1520 - val_loss: 0.1534
# Epoch 48/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1511 - val_loss: 0.1511
# Epoch 49/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1513 - val_loss: 0.1502
# Epoch 50/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1503 - val_loss: 0.1498
# Epoch 51/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1496 - val_loss: 0.1501
# Epoch 52/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1489 - val_loss: 0.1492
# Epoch 53/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1485 - val_loss: 0.1524
# Epoch 54/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1486 - val_loss: 0.1499
# Epoch 55/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1477 - val_loss: 0.1483
# Epoch 56/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1473 - val_loss: 0.1508
# Epoch 57/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1467 - val_loss: 0.1488
# Epoch 58/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1466 - val_loss: 0.1483
# Epoch 59/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1463 - val_loss: 0.1483
# Epoch 60/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1458 - val_loss: 0.1504
# Epoch 61/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1461 - val_loss: 0.1480
# Epoch 62/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1454 - val_loss: 0.1497
# Epoch 63/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1449 - val_loss: 0.1485
# Epoch 64/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1448 - val_loss: 0.1486
# Epoch 65/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1449 - val_loss: 0.1481
# Epoch 66/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1449 - val_loss: 0.1470
# Epoch 67/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1444 - val_loss: 0.1477
# Epoch 68/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1440 - val_loss: 0.1478
# Epoch 69/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1436 - val_loss: 0.1492
# Epoch 70/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1441 - val_loss: 0.1483
# Epoch 71/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1433 - val_loss: 0.1478
# Epoch 72/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1431 - val_loss: 0.1505
# Epoch 73/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1430 - val_loss: 0.1491
# Epoch 74/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1431 - val_loss: 0.1486
# Epoch 75/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1433 - val_loss: 0.1480
# Epoch 76/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1428 - val_loss: 0.1478
# Epoch 77/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1424 - val_loss: 0.1488
# Epoch 78/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1425 - val_loss: 0.1509
# Epoch 79/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1422 - val_loss: 0.1477
# Epoch 80/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1418 - val_loss: 0.1490
# Epoch 81/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1418 - val_loss: 0.1464
# Epoch 82/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1417 - val_loss: 0.1471
# Epoch 83/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1421 - val_loss: 0.1472
# Epoch 84/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1414 - val_loss: 0.1470
# Epoch 85/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1414 - val_loss: 0.1479
# Epoch 86/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1411 - val_loss: 0.1472
# Epoch 87/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1409 - val_loss: 0.1470
# Epoch 88/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1408 - val_loss: 0.1510
# Epoch 89/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1412 - val_loss: 0.1472
# Epoch 90/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1407 - val_loss: 0.1475
# Epoch 91/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1403 - val_loss: 0.1462
# Epoch 92/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1404 - val_loss: 0.1457
# Epoch 93/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1406 - val_loss: 0.1468
# Epoch 94/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1398 - val_loss: 0.1546
# Epoch 95/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1401 - val_loss: 0.1470
# Epoch 96/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1401 - val_loss: 0.1487
# Epoch 97/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1395 - val_loss: 0.1470
# Epoch 98/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1392 - val_loss: 0.1469
# Epoch 99/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1394 - val_loss: 0.1474
# Epoch 100/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1394 - val_loss: 0.1463
# Epoch 101/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1390 - val_loss: 0.1463
# Epoch 102/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1389 - val_loss: 0.1555
# Epoch 103/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1391 - val_loss: 0.1481
# Epoch 104/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1391 - val_loss: 0.1456
# Epoch 105/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1389 - val_loss: 0.1465
# Epoch 106/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1385 - val_loss: 0.1509
# Epoch 107/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1388 - val_loss: 0.1480
# Epoch 108/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1384 - val_loss: 0.1476
# Epoch 109/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1387 - val_loss: 0.1469
# Epoch 110/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1388 - val_loss: 0.1457
# Epoch 111/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1386 - val_loss: 0.1462
# Epoch 112/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1382 - val_loss: 0.1481
# Epoch 113/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1383 - val_loss: 0.1467
# Epoch 114/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1379 - val_loss: 0.1464
# Epoch 115/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1380 - val_loss: 0.1457
# Epoch 116/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1377 - val_loss: 0.1472
# Epoch 117/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1377 - val_loss: 0.1467
# Epoch 118/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1380 - val_loss: 0.1458
# Epoch 119/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1379 - val_loss: 0.1454
# Epoch 120/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1382 - val_loss: 0.1460
# Epoch 121/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1375 - val_loss: 0.1461
# Epoch 122/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1375 - val_loss: 0.1457
# Epoch 123/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1373 - val_loss: 0.1461
# Epoch 124/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1375 - val_loss: 0.1454
# Epoch 125/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1376 - val_loss: 0.1463
# Epoch 126/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1371 - val_loss: 0.1475
# Epoch 127/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1373 - val_loss: 0.1457
# Epoch 128/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1373 - val_loss: 0.1456
# Epoch 129/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1374 - val_loss: 0.1457
# Epoch 130/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1373 - val_loss: 0.1473
# Epoch 131/200
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1375 - val_loss: 0.1451
# Epoch 132/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1368 - val_loss: 0.1458
# Epoch 133/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1371 - val_loss: 0.1449
# Epoch 134/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1366 - val_loss: 0.1456
# Epoch 135/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1370 - val_loss: 0.1457
# Epoch 136/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1370 - val_loss: 0.1448
# Epoch 137/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1366 - val_loss: 0.1462
# Epoch 138/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1367 - val_loss: 0.1456
# Epoch 139/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1368 - val_loss: 0.1459
# Epoch 140/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1364 - val_loss: 0.1454
# Epoch 141/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1361 - val_loss: 0.1456
# Epoch 142/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1361 - val_loss: 0.1453
# Epoch 143/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1370 - val_loss: 0.1449
# Epoch 144/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1366 - val_loss: 0.1452
# Epoch 145/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1358 - val_loss: 0.1510
# Epoch 146/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1367 - val_loss: 0.1472
# Epoch 147/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1363 - val_loss: 0.1456
# Epoch 148/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1365 - val_loss: 0.1455
# Epoch 149/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1363 - val_loss: 0.1459
# Epoch 150/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1363 - val_loss: 0.1453
# Epoch 151/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1361 - val_loss: 0.1458
# Epoch 152/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1360 - val_loss: 0.1458
# Epoch 153/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1361 - val_loss: 0.1454
# Epoch 154/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1358 - val_loss: 0.1468
# Epoch 155/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1359 - val_loss: 0.1466
# Epoch 156/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1356 - val_loss: 0.1453
# Epoch 157/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1361 - val_loss: 0.1452
# Epoch 158/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1358 - val_loss: 0.1457
# Epoch 159/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1357 - val_loss: 0.1451
# Epoch 160/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1357 - val_loss: 0.1472
# Epoch 161/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1360 - val_loss: 0.1462
# Epoch 162/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1356 - val_loss: 0.1452
# Epoch 163/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1358 - val_loss: 0.1449
# Epoch 164/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1357 - val_loss: 0.1450
# Epoch 165/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1355 - val_loss: 0.1458
# Epoch 166/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1359 - val_loss: 0.1452
# Epoch 167/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1357 - val_loss: 0.1458
# Epoch 168/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1356 - val_loss: 0.1446
# Epoch 169/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1351 - val_loss: 0.1461
# Epoch 170/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1354 - val_loss: 0.1445
# Epoch 171/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1353 - val_loss: 0.1464
# Epoch 172/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1355 - val_loss: 0.1443
# Epoch 173/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1350 - val_loss: 0.1449
# Epoch 174/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1351 - val_loss: 0.1443
# Epoch 175/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1351 - val_loss: 0.1451
# Epoch 176/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1349 - val_loss: 0.1457
# Epoch 177/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1354 - val_loss: 0.1458
# Epoch 178/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1347 - val_loss: 0.1468
# Epoch 179/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1353 - val_loss: 0.1455
# Epoch 180/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1349 - val_loss: 0.1455
# Epoch 181/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1352 - val_loss: 0.1471
# Epoch 182/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1347 - val_loss: 0.1456
# Epoch 183/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1351 - val_loss: 0.1447
# Epoch 184/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1349 - val_loss: 0.1451
# Epoch 185/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1354 - val_loss: 0.1454
# Epoch 186/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1350 - val_loss: 0.1442
# Epoch 187/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1347 - val_loss: 0.1452
# Epoch 188/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1348 - val_loss: 0.1447
# Epoch 189/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1351 - val_loss: 0.1463
# Epoch 190/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1346 - val_loss: 0.1451
# Epoch 191/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1350 - val_loss: 0.1459
# Epoch 192/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1348 - val_loss: 0.1449
# Epoch 193/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1347 - val_loss: 0.1442
# Epoch 194/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1342 - val_loss: 0.1468
# Epoch 195/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1347 - val_loss: 0.1437
# Epoch 196/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1350 - val_loss: 0.1445
# Epoch 197/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1347 - val_loss: 0.1446
# Epoch 198/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1347 - val_loss: 0.1441
# Epoch 199/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1342 - val_loss: 0.1442
# Epoch 200/200
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1347 - val_loss: 0.1446

# %%
# train data에 대한 예측 값
AE_train_pred = AE.predict(X_train)

# 실제 값과 예측 값 사이의 차이인 MSE값을 reconstruction error로 정의 -> Novelty Score
train_mse = np.mean(np.power(X_train - AE_train_pred, 2), axis=1)
train_mse = pd.DataFrame({'Reconstruction_error': train_mse})

# train 데이터에 대한 novelty score 기준 상위 10% 의 값을 임계치로 설정
AE_thresh = np.percentile(sorted(train_mse['Reconstruction_error']), 90)

# test data에 대한 예측 값
AE_test_pred = AE.predict(X_test)

# 실제 값과 예측 값 사이의 차이인 MSE값을 reconstruction error로 정의
test_mse = np.mean(np.power(X_test - AE_test_pred, 2), axis=1)

# classifier
# AE_thresh 기준, test_mse 값이 더 크면 이상(1), 작으면 정상(0)으로 분류
AE_test_df = []

def novelty_classifier(novelty_score):
    for i in range(len(novelty_score)):
        if novelty_score[i] > AE_thresh:
            AE_test_df.append(1)
        else:
            AE_test_df.append(0)

novelty_classifier(test_mse.values)

print("accuracy: ", accuracy_score(y_test, AE_test_df))
print("recall: ", round(recall_score(y_test, AE_test_df),3))
print("precision: ", round(precision_score(y_test, AE_test_df),3))
print("f1-score: ", round(f1_score(y_test, AE_test_df),3))
# Out:
# 334/334 [==============================] - 1s 1ms/step
# 17/17 [==============================] - 0s 2ms/step
# accuracy:  0.8288461538461539
# recall:  0.769
# precision:  0.873
# f1-score:  0.818
